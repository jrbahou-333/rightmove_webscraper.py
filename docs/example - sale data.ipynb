# %% [markdown]
# # `rightmove_webscraper.py`
# # Example - Get Sale Data

# %%
# Setup:
import os, sys
sys.path.append(os.path.dirname(os.getcwd()))
from rightmove_webscraper import RightmoveData

# %%
url = "https://www.rightmove.co.uk/property-for-sale/find.html?\searchType=SALE&locationIdentifier=REGION%5E94346"
rmd = RightmoveData(url)
print(rmd.get_results["type"].head(40).tolist())
print(rmd.get_results["type"].value_counts(dropna=False))
rmd.results_count
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# /var/folders/ck/2s_qqpg117j1tld3r0dw39c80000gn/T/ipykernel_23174/2684030507.py:1: SyntaxWarning: invalid escape sequence '\s'
#   url = "https://www.rightmove.co.uk/property-for-sale/find.html?\searchType=SALE&locationIdentifier=REGION%5E94346"
# ['Apartment', 'Penthouse', 'Apartment', 'Apartment', 'Apartment', 'Apartment', 'Apartment', 'Apartment', 'Apartment', 'Apartment', 'Apartment', 'Apartment', 'Apartment', 'Apartment', 'Apartment', 'Flat', 'Flat', 'Apartment', 'Flat', 'Duplex', 'Penthouse', 'Apartment', 'Flat', 'Apartment', 'Apartment', 'Flat', 'Flat', 'Apartment', 'Apartment', 'Apartment', 'Apartment', 'Apartment', 'Apartment', 'Apartment', 'Flat', 'Apartment', 'Apartment', 'Apartment', 'Flat', 'Apartment']
# type
# Apartment    157
# Flat          35
# Studio        15
# Penthouse      2
# Duplex         1
# Land           1
# Name: count, dtype: int64
# 211

# %% [markdown]
# The `average_price` attribute gives the mean price of all results returned:

# %%
print(f"£{rmd.average_price:,.0f}")

# %% [markdown]
# The `summary` attribute creates a Pandas DataFrame summarising the results by count and mean price:

# %%
rmd.summary()

# %% [markdown]
# By default `summary` is group by number of bedrooms, but can also be grouped by any column in the DataFrame at the `get_results` attribute:

# %%
rmd.summary(by="postcode")

# %% [markdown]
# The `get_results` attribute returns all listings in a Pandas dataframe:

# %%
rmd.get_results.tail()
